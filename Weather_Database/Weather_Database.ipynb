# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
# len(cities)

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng" : city_lng,
                          "Max Temp" : city_max_temp,
                         "Humidity" : city_humidity,
                         "Cloudiness" : city_clouds,
                         "Wind Speed" : city_wind,
                         "Country" : city_country,
                         "Current Description" : city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nampula
# Processing Record 2 of Set 1 | padang
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | port hardy
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | hovd
# Processing Record 8 of Set 1 | karasjok
# Processing Record 9 of Set 1 | bilecik
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | jalu
# Processing Record 14 of Set 1 | daman
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | fortuna
# Processing Record 17 of Set 1 | ossora
# Processing Record 18 of Set 1 | mokhsogollokh
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | wattegama
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | shingu
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | samarai
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 1 | roma
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | tabas
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 1 | lubango
# Processing Record 37 of Set 1 | high level
# Processing Record 38 of Set 1 | atar
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | quatre cocos
# Processing Record 44 of Set 1 | yicheng
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | cherskiy
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | fayaoue
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | tura
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | brae
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | srednekolymsk
# Processing Record 11 of Set 2 | rio grande
# Processing Record 12 of Set 2 | hambantota
# Processing Record 13 of Set 2 | caravelas
# Processing Record 14 of Set 2 | road town
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | amapa
# Processing Record 17 of Set 2 | san jose de guanipa
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | warragul
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 23 of Set 2 | warrington
# Processing Record 24 of Set 2 | la libertad
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | cidreira
# Processing Record 27 of Set 2 | san cristobal
# Processing Record 28 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | juneau
# Processing Record 33 of Set 2 | koppang
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | beisfjord
# Processing Record 37 of Set 2 | sao filipe
# Processing Record 38 of Set 2 | douazeci si trei august
# Processing Record 39 of Set 2 | chimbote
# Processing Record 40 of Set 2 | novopokrovka
# Processing Record 41 of Set 2 | dodge city
# Processing Record 42 of Set 2 | touros
# Processing Record 43 of Set 2 | ouadda
# Processing Record 44 of Set 2 | viedma
# Processing Record 45 of Set 2 | vila velha
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | dondo
# Processing Record 49 of Set 2 | olga
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 3 | osorno
# Processing Record 3 of Set 3 | noumea
# Processing Record 4 of Set 3 | kungsbacka
# Processing Record 5 of Set 3 | sioux lookout
# Processing Record 6 of Set 3 | narsaq
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | ibra
# Processing Record 9 of Set 3 | igarka
# Processing Record 10 of Set 3 | havoysund
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | nouadhibou
# Processing Record 13 of Set 3 | caucaia
# Processing Record 14 of Set 3 | almansa
# Processing Record 15 of Set 3 | ushuaia
# Processing Record 16 of Set 3 | magui
# City not found. Skipping...
# Processing Record 17 of Set 3 | salalah
# Processing Record 18 of Set 3 | verkhnyaya inta
# Processing Record 19 of Set 3 | pitimbu
# Processing Record 20 of Set 3 | namsos
# Processing Record 21 of Set 3 | pathein
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | taunggyi
# Processing Record 27 of Set 3 | hyeres
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | poronaysk
# Processing Record 30 of Set 3 | nishihara
# Processing Record 31 of Set 3 | belmonte
# Processing Record 32 of Set 3 | leningradskiy
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | muros
# Processing Record 36 of Set 3 | slanic-moldova
# Processing Record 37 of Set 3 | margate
# Processing Record 38 of Set 3 | soyo
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | luena
# Processing Record 41 of Set 3 | hokitika
# Processing Record 42 of Set 3 | butaritari
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | rocha
# Processing Record 46 of Set 3 | christchurch
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | vostok
# Processing Record 49 of Set 3 | port hedland
# Processing Record 50 of Set 3 | namatanai
# Processing Record 1 of Set 4 | manggar
# Processing Record 2 of Set 4 | taquarituba
# Processing Record 3 of Set 4 | teguldet
# Processing Record 4 of Set 4 | krasnoselkup
# Processing Record 5 of Set 4 | pisco
# Processing Record 6 of Set 4 | maracacume
# Processing Record 7 of Set 4 | gursu
# Processing Record 8 of Set 4 | auki
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | coruripe
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | saint-georges
# Processing Record 13 of Set 4 | kieta
# Processing Record 14 of Set 4 | lerwick
# Processing Record 15 of Set 4 | port lincoln
# Processing Record 16 of Set 4 | porto novo
# Processing Record 17 of Set 4 | aksarayskiy
# Processing Record 18 of Set 4 | agua verde
# Processing Record 19 of Set 4 | luganville
# Processing Record 20 of Set 4 | riyadh
# Processing Record 21 of Set 4 | liverpool
# Processing Record 22 of Set 4 | tasiilaq
# Processing Record 23 of Set 4 | talavera de la reina
# Processing Record 24 of Set 4 | moss point
# Processing Record 25 of Set 4 | yumen
# Processing Record 26 of Set 4 | marica
# Processing Record 27 of Set 4 | gornopravdinsk
# Processing Record 28 of Set 4 | tuy hoa
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | gwadar
# Processing Record 31 of Set 4 | milkovo
# Processing Record 32 of Set 4 | wanning
# Processing Record 33 of Set 4 | lang son
# Processing Record 34 of Set 4 | buala
# Processing Record 35 of Set 4 | launceston
# Processing Record 36 of Set 4 | turukhansk
# Processing Record 37 of Set 4 | svetlogorsk
# Processing Record 38 of Set 4 | mossendjo
# Processing Record 39 of Set 4 | dengzhou
# Processing Record 40 of Set 4 | sept-iles
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | lata
# Processing Record 43 of Set 4 | shimoda
# Processing Record 44 of Set 4 | kitimat
# Processing Record 45 of Set 4 | waipawa
# Processing Record 46 of Set 4 | barabai
# Processing Record 47 of Set 4 | sidi ali
# Processing Record 48 of Set 4 | khandyga
# Processing Record 49 of Set 4 | castro
# Processing Record 50 of Set 4 | valparaiso
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | ondjiva
# Processing Record 3 of Set 5 | yulara
# Processing Record 4 of Set 5 | madhipura
# Processing Record 5 of Set 5 | lazaro cardenas
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | vao
# Processing Record 8 of Set 5 | nybro
# Processing Record 9 of Set 5 | cabedelo
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | gibsons
# Processing Record 12 of Set 5 | saldanha
# Processing Record 13 of Set 5 | moree
# Processing Record 14 of Set 5 | coihaique
# Processing Record 15 of Set 5 | bunia
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | chuy
# Processing Record 18 of Set 5 | ornskoldsvik
# Processing Record 19 of Set 5 | comodoro rivadavia
# Processing Record 20 of Set 5 | orlik
# Processing Record 21 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 5 | tautira
# Processing Record 23 of Set 5 | tomatlan
# Processing Record 24 of Set 5 | fantanele
# Processing Record 25 of Set 5 | zaozerne
# Processing Record 26 of Set 5 | dikson
# Processing Record 27 of Set 5 | kashi
# Processing Record 28 of Set 5 | zhigansk
# Processing Record 29 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 30 of Set 5 | puerto ayora
# Processing Record 31 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 5 | firozpur
# Processing Record 33 of Set 5 | kichera
# Processing Record 34 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 5 | san rafael
# Processing Record 36 of Set 5 | namibe
# Processing Record 37 of Set 5 | matay
# Processing Record 38 of Set 5 | ponta delgada
# Processing Record 39 of Set 5 | morondava
# Processing Record 40 of Set 5 | nieuw amsterdam
# Processing Record 41 of Set 5 | dunedin
# Processing Record 42 of Set 5 | axim
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | nizhniy kuranakh
# Processing Record 45 of Set 5 | bambous virieux
# Processing Record 46 of Set 5 | chilca
# Processing Record 47 of Set 5 | acajutla
# Processing Record 48 of Set 5 | vallenar
# Processing Record 49 of Set 5 | camacha
# Processing Record 50 of Set 5 | corinto
# Processing Record 1 of Set 6 | izvoarele
# Processing Record 2 of Set 6 | areosa
# Processing Record 3 of Set 6 | acapulco
# Processing Record 4 of Set 6 | vestmannaeyjar
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | gat
# Processing Record 7 of Set 6 | abha
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | yellowknife
# Processing Record 10 of Set 6 | vila franca do campo
# Processing Record 11 of Set 6 | ritchie
# Processing Record 12 of Set 6 | nakasongola
# Processing Record 13 of Set 6 | bathsheba
# Processing Record 14 of Set 6 | fuxin
# Processing Record 15 of Set 6 | daru
# Processing Record 16 of Set 6 | broken hill
# Processing Record 17 of Set 6 | talcahuano
# Processing Record 18 of Set 6 | lander
# Processing Record 19 of Set 6 | norman wells
# Processing Record 20 of Set 6 | mercedes
# Processing Record 21 of Set 6 | necochea
# Processing Record 22 of Set 6 | udachnyy
# Processing Record 23 of Set 6 | yar-sale
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 6 | kaduqli
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | nelson bay
# Processing Record 28 of Set 6 | estelle
# Processing Record 29 of Set 6 | makakilo city
# Processing Record 30 of Set 6 | bud
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | timmins
# Processing Record 33 of Set 6 | provideniya
# Processing Record 34 of Set 6 | emerald
# Processing Record 35 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 6 | haines junction
# Processing Record 37 of Set 6 | sabha
# Processing Record 38 of Set 6 | klaksvik
# Processing Record 39 of Set 6 | naze
# Processing Record 40 of Set 6 | porto walter
# Processing Record 41 of Set 6 | vieste
# Processing Record 42 of Set 6 | port elizabeth
# Processing Record 43 of Set 6 | rawson
# Processing Record 44 of Set 6 | karonga
# Processing Record 45 of Set 6 | sorland
# Processing Record 46 of Set 6 | saint anthony
# Processing Record 47 of Set 6 | port blair
# Processing Record 48 of Set 6 | pangkalanbuun
# Processing Record 49 of Set 6 | san jeronimo
# Processing Record 50 of Set 6 | husavik
# Processing Record 1 of Set 7 | chenzhou
# Processing Record 2 of Set 7 | general roca
# Processing Record 3 of Set 7 | taitung
# Processing Record 4 of Set 7 | kutum
# Processing Record 5 of Set 7 | dukhovnitskoye
# Processing Record 6 of Set 7 | bonanza
# Processing Record 7 of Set 7 | althofen
# Processing Record 8 of Set 7 | bulungu
# Processing Record 9 of Set 7 | primero de marzo
# Processing Record 10 of Set 7 | los llanos de aridane
# Processing Record 11 of Set 7 | ketchikan
# Processing Record 12 of Set 7 | malanville
# Processing Record 13 of Set 7 | qixingtai
# Processing Record 14 of Set 7 | linping
# Processing Record 15 of Set 7 | kormilovka
# Processing Record 16 of Set 7 | mount gambier
# Processing Record 17 of Set 7 | sao joao dos patos
# Processing Record 18 of Set 7 | great yarmouth
# Processing Record 19 of Set 7 | turbat
# Processing Record 20 of Set 7 | skjervoy
# Processing Record 21 of Set 7 | san patricio
# Processing Record 22 of Set 7 | hervey bay
# Processing Record 23 of Set 7 | ust-kulom
# Processing Record 24 of Set 7 | mordovo
# Processing Record 25 of Set 7 | pacific grove
# Processing Record 26 of Set 7 | anuradhapura
# Processing Record 27 of Set 7 | bairiki
# Processing Record 28 of Set 7 | kuytun
# Processing Record 29 of Set 7 | orange cove
# Processing Record 30 of Set 7 | tynda
# Processing Record 31 of Set 7 | kundiawa
# Processing Record 32 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 7 | skowhegan
# Processing Record 34 of Set 7 | camacupa
# Processing Record 35 of Set 7 | kisangani
# Processing Record 36 of Set 7 | isangel
# Processing Record 37 of Set 7 | ulladulla
# Processing Record 38 of Set 7 | ahipara
# Processing Record 39 of Set 7 | cap-aux-meules
# Processing Record 40 of Set 7 | kyren
# Processing Record 41 of Set 7 | lodja
# Processing Record 42 of Set 7 | miri
# Processing Record 43 of Set 7 | sao jose da coroa grande
# Processing Record 44 of Set 7 | calabozo
# Processing Record 45 of Set 7 | bereda
# Processing Record 46 of Set 7 | umm lajj
# Processing Record 47 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 7 | kamenka
# Processing Record 49 of Set 7 | winsum
# Processing Record 50 of Set 7 | boguchany
# Processing Record 1 of Set 8 | mankono
# Processing Record 2 of Set 8 | nathdwara
# Processing Record 3 of Set 8 | lixourion
# Processing Record 4 of Set 8 | tocopilla
# Processing Record 5 of Set 8 | nemuro
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | richards bay
# Processing Record 8 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 8 | huilong
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | artvin
# Processing Record 12 of Set 8 | codrington
# Processing Record 13 of Set 8 | pombas
# Processing Record 14 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 8 | cotonou
# Processing Record 16 of Set 8 | nenjiang
# Processing Record 17 of Set 8 | salinas
# Processing Record 18 of Set 8 | coos bay
# Processing Record 19 of Set 8 | lahan
# Processing Record 20 of Set 8 | rabo de peixe
# Processing Record 21 of Set 8 | tiksi
# Processing Record 22 of Set 8 | elko
# Processing Record 23 of Set 8 | astana
# Processing Record 24 of Set 8 | mazamet
# Processing Record 25 of Set 8 | renala khurd
# Processing Record 26 of Set 8 | tual
# Processing Record 27 of Set 8 | adrar
# Processing Record 28 of Set 8 | januaria
# Processing Record 29 of Set 8 | alice springs
# Processing Record 30 of Set 8 | alyangula
# Processing Record 31 of Set 8 | nanakuli
# Processing Record 32 of Set 8 | korablino
# Processing Record 33 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 34 of Set 8 | dingle
# Processing Record 35 of Set 8 | makaha
# Processing Record 36 of Set 8 | aykhal
# Processing Record 37 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 8 | kesan
# Processing Record 39 of Set 8 | shaoyang
# Processing Record 40 of Set 8 | buraydah
# Processing Record 41 of Set 8 | morant bay
# Processing Record 42 of Set 8 | mon
# Processing Record 43 of Set 8 | portland
# Processing Record 44 of Set 8 | neiafu
# Processing Record 45 of Set 8 | caidian
# Processing Record 46 of Set 8 | geraldton
# Processing Record 47 of Set 8 | tayoltita
# Processing Record 48 of Set 8 | sosnovo-ozerskoye
# Processing Record 49 of Set 8 | biscarrosse
# Processing Record 50 of Set 8 | san andres
# Processing Record 1 of Set 9 | naron
# Processing Record 2 of Set 9 | chikwawa
# Processing Record 3 of Set 9 | saint-felicien
# Processing Record 4 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 9 | dodoma
# Processing Record 6 of Set 9 | vagur
# Processing Record 7 of Set 9 | coxim
# Processing Record 8 of Set 9 | yerbogachen
# Processing Record 9 of Set 9 | skibbereen
# Processing Record 10 of Set 9 | marzuq
# Processing Record 11 of Set 9 | aswan
# Processing Record 12 of Set 9 | longyearbyen
# Processing Record 13 of Set 9 | tommot
# Processing Record 14 of Set 9 | saint-pierre
# Processing Record 15 of Set 9 | ballina
# Processing Record 16 of Set 9 | nueva loja
# Processing Record 17 of Set 9 | asfi
# Processing Record 18 of Set 9 | kota bahru
# Processing Record 19 of Set 9 | asau
# Processing Record 20 of Set 9 | sai buri
# Processing Record 21 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 9 | yamada
# Processing Record 23 of Set 9 | marathon
# Processing Record 24 of Set 9 | kuryk
# Processing Record 25 of Set 9 | umm kaddadah
# Processing Record 26 of Set 9 | kabelvag
# Processing Record 27 of Set 9 | tilichiki
# Processing Record 28 of Set 9 | tairua
# Processing Record 29 of Set 9 | talnakh
# Processing Record 30 of Set 9 | leh
# Processing Record 31 of Set 9 | yenagoa
# Processing Record 32 of Set 9 | wamba
# Processing Record 33 of Set 9 | college
# Processing Record 34 of Set 9 | callander
# Processing Record 35 of Set 9 | te anau
# Processing Record 36 of Set 9 | ajaccio
# Processing Record 37 of Set 9 | bousse
# Processing Record 38 of Set 9 | garden city
# Processing Record 39 of Set 9 | hays
# Processing Record 40 of Set 9 | sonoita
# Processing Record 41 of Set 9 | alenquer
# Processing Record 42 of Set 9 | bosobolo
# Processing Record 43 of Set 9 | souillac
# Processing Record 44 of Set 9 | grand gaube
# Processing Record 45 of Set 9 | cayenne
# Processing Record 46 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 9 | encarnacion
# Processing Record 48 of Set 9 | tessalit
# Processing Record 49 of Set 9 | taksimo
# Processing Record 50 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 2 of Set 10 | panzhihua
# Processing Record 3 of Set 10 | castanheira de pera
# Processing Record 4 of Set 10 | rudbar
# Processing Record 5 of Set 10 | kloulklubed
# Processing Record 6 of Set 10 | flinders
# Processing Record 7 of Set 10 | lagoa
# Processing Record 8 of Set 10 | kondopoga
# Processing Record 9 of Set 10 | cabo san lucas
# Processing Record 10 of Set 10 | klyuchi
# Processing Record 11 of Set 10 | lumeje
# Processing Record 12 of Set 10 | shaunavon
# Processing Record 13 of Set 10 | ust-tsilma
# Processing Record 14 of Set 10 | algiers
# Processing Record 15 of Set 10 | hofn
# Processing Record 16 of Set 10 | unjha
# Processing Record 17 of Set 10 | labytnangi
# Processing Record 18 of Set 10 | korla
# Processing Record 19 of Set 10 | moussoro
# Processing Record 20 of Set 10 | artyom
# Processing Record 21 of Set 10 | tupik
# Processing Record 22 of Set 10 | lavumisa
# Processing Record 23 of Set 10 | darhan
# Processing Record 24 of Set 10 | kikwit
# Processing Record 25 of Set 10 | ahuimanu
# Processing Record 26 of Set 10 | goderich
# Processing Record 27 of Set 10 | kaniama
# Processing Record 28 of Set 10 | bubaque
# Processing Record 29 of Set 10 | la sarre
# Processing Record 30 of Set 10 | karoi
# Processing Record 31 of Set 10 | iqaluit
# Processing Record 32 of Set 10 | baglung
# Processing Record 33 of Set 10 | yatou
# Processing Record 34 of Set 10 | visalia
# Processing Record 35 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 10 | caetite
# Processing Record 37 of Set 10 | ostrovnoy
# Processing Record 38 of Set 10 | hasaki
# Processing Record 39 of Set 10 | kanigiri
# Processing Record 40 of Set 10 | kangaatsiaq
# Processing Record 41 of Set 10 | jumla
# Processing Record 42 of Set 10 | hamilton
# Processing Record 43 of Set 10 | bafra
# Processing Record 44 of Set 10 | abu dhabi
# Processing Record 45 of Set 10 | banda aceh
# Processing Record 46 of Set 10 | roald
# Processing Record 47 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 10 | katsuura
# Processing Record 49 of Set 10 | bodden town
# Processing Record 50 of Set 10 | nevers
# Processing Record 1 of Set 11 | boda
# Processing Record 2 of Set 11 | krasnoyarskiy
# Processing Record 3 of Set 11 | hattiesburg
# Processing Record 4 of Set 11 | cedar city
# Processing Record 5 of Set 11 | krutinka
# Processing Record 6 of Set 11 | ilhabela
# Processing Record 7 of Set 11 | kangaba
# Processing Record 8 of Set 11 | nizwa
# Processing Record 9 of Set 11 | mount isa
# Processing Record 10 of Set 11 | mehamn
# Processing Record 11 of Set 11 | luau
# Processing Record 12 of Set 11 | bilma
# Processing Record 13 of Set 11 | woodward
# Processing Record 14 of Set 11 | stykkisholmur
# Processing Record 15 of Set 11 | cheltenham
# Processing Record 16 of Set 11 | nome
# Processing Record 17 of Set 11 | fallon
# Processing Record 18 of Set 11 | bjala
# City not found. Skipping...
# Processing Record 19 of Set 11 | zheleznodorozhnyy
# Processing Record 20 of Set 11 | andenes
# Processing Record 21 of Set 11 | wad rawah
# Processing Record 22 of Set 11 | hay river
# Processing Record 23 of Set 11 | cururupu
# Processing Record 24 of Set 11 | pietermaritzburg
# Processing Record 25 of Set 11 | volgodonsk
# Processing Record 26 of Set 11 | gorontalo
# Processing Record 27 of Set 11 | taoudenni
# Processing Record 28 of Set 11 | plyussa
# Processing Record 29 of Set 11 | birin
# Processing Record 30 of Set 11 | kurchum
# Processing Record 31 of Set 11 | varfurile
# Processing Record 32 of Set 11 | boa vista
# Processing Record 33 of Set 11 | north branch
# Processing Record 34 of Set 11 | humberto de campos
# Processing Record 35 of Set 11 | burhaniye
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 38 of Set 11 | brandon
# Processing Record 39 of Set 11 | priego de cordoba
# Processing Record 40 of Set 11 | harper
# Processing Record 41 of Set 11 | kawalu
# Processing Record 42 of Set 11 | ukhta
# Processing Record 43 of Set 11 | boksitogorsk
# Processing Record 44 of Set 11 | catacocha
# Processing Record 45 of Set 11 | mucurici
# Processing Record 46 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 47 of Set 11 | maneadero
# Processing Record 48 of Set 11 | mayo
# Processing Record 49 of Set 11 | paso de los toros
# Processing Record 50 of Set 11 | youkounkoun
# Processing Record 1 of Set 12 | formosa
# Processing Record 2 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 12 | koyilandi
# City not found. Skipping...
# Processing Record 4 of Set 12 | chulman
# Processing Record 5 of Set 12 | oktyabrskiy
# Processing Record 6 of Set 12 | nong bua
# Processing Record 7 of Set 12 | santa luzia
# Processing Record 8 of Set 12 | pucallpa
# Processing Record 9 of Set 12 | trinidad
# Processing Record 10 of Set 12 | lima
# Processing Record 11 of Set 12 | sisimiut
# Processing Record 12 of Set 12 | puerto escondido
# Processing Record 13 of Set 12 | aldan
# Processing Record 14 of Set 12 | nayoro
# Processing Record 15 of Set 12 | zeya
# Processing Record 16 of Set 12 | chateaudun
# Processing Record 17 of Set 12 | aklavik
# Processing Record 18 of Set 12 | wajir
# Processing Record 19 of Set 12 | berlevag
# Processing Record 20 of Set 12 | lasa
# Processing Record 21 of Set 12 | barra do garcas
# Processing Record 22 of Set 12 | willowmore
# Processing Record 23 of Set 12 | obo
# Processing Record 24 of Set 12 | praia
# Processing Record 25 of Set 12 | oranjemund
# Processing Record 26 of Set 12 | moron
# Processing Record 27 of Set 12 | moctezuma
# Processing Record 28 of Set 12 | arlit
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | komsomolskiy
# Processing Record 31 of Set 12 | genhe
# Processing Record 32 of Set 12 | semme
# Processing Record 33 of Set 12 | codajas
# Processing Record 34 of Set 12 | mackay
# Processing Record 35 of Set 12 | tallahassee
# Processing Record 36 of Set 12 | senden
# Processing Record 37 of Set 12 | evensk
# Processing Record 38 of Set 12 | barra
# Processing Record 39 of Set 12 | balkhash
# Processing Record 40 of Set 12 | tarbes
# Processing Record 41 of Set 12 | erzin
# Processing Record 42 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 43 of Set 12 | saryg-sep
# Processing Record 44 of Set 12 | belyy yar
# Processing Record 45 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | warri
# Processing Record 47 of Set 12 | sorkjosen
# Processing Record 48 of Set 12 | tanabi
# Processing Record 49 of Set 12 | castro-urdiales
# Processing Record 50 of Set 12 | picos
# Processing Record 1 of Set 13 | kudahuvadhoo
# Processing Record 2 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 3 of Set 13 | healdsburg
# Processing Record 4 of Set 13 | grindavik
# Processing Record 5 of Set 13 | barra do corda
# Processing Record 6 of Set 13 | gizo
# Processing Record 7 of Set 13 | sibolga
# Processing Record 8 of Set 13 | karratha
# Processing Record 9 of Set 13 | raga
# Processing Record 10 of Set 13 | beruwala
# Processing Record 11 of Set 13 | pericos
# Processing Record 12 of Set 13 | dakar
# Processing Record 13 of Set 13 | malinovoye ozero
# Processing Record 14 of Set 13 | marsh harbour
# Processing Record 15 of Set 13 | lazarev
# Processing Record 16 of Set 13 | dubti
# Processing Record 17 of Set 13 | sistranda
# Processing Record 18 of Set 13 | kurikka
# Processing Record 19 of Set 13 | sarakhs
# Processing Record 20 of Set 13 | carutapera
# Processing Record 21 of Set 13 | kahului
# Processing Record 22 of Set 13 | eldorado
# Processing Record 23 of Set 13 | shahr-e babak
# Processing Record 24 of Set 13 | kwinana
# Processing Record 25 of Set 13 | broome
# Processing Record 26 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 27 of Set 13 | khakhea
# Processing Record 28 of Set 13 | pontianak
# Processing Record 29 of Set 13 | shimanovsk
# Processing Record 30 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 31 of Set 13 | karimganj
# Processing Record 32 of Set 13 | talaya
# Processing Record 33 of Set 13 | severomuysk
# Processing Record 34 of Set 13 | novomikhaylovskiy
# Processing Record 35 of Set 13 | praia da vitoria
# Processing Record 36 of Set 13 | fairbanks
# Processing Record 37 of Set 13 | smithers
# Processing Record 38 of Set 13 | ola
# Processing Record 39 of Set 13 | lichtenburg
# Processing Record 40 of Set 13 | chara
# Processing Record 41 of Set 13 | wewak
# Processing Record 42 of Set 13 | sola
# Processing Record 43 of Set 13 | khani
# Processing Record 44 of Set 13 | mareeba
# Processing Record 45 of Set 13 | mecca
# Processing Record 46 of Set 13 | beyneu
# Processing Record 47 of Set 13 | bulgan
# Processing Record 48 of Set 13 | havre-saint-pierre
# Processing Record 49 of Set 13 | teya
# Processing Record 50 of Set 13 | bria
# Processing Record 1 of Set 14 | atambua
# Processing Record 2 of Set 14 | camopi
# Processing Record 3 of Set 14 | henties bay
# Processing Record 4 of Set 14 | el molino
# Processing Record 5 of Set 14 | winslow
# Processing Record 6 of Set 14 | cockburn town
# Processing Record 7 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 14 | jining
# Processing Record 9 of Set 14 | carmen
# Processing Record 10 of Set 14 | porto seguro
# Processing Record 11 of Set 14 | at-bashi
# Processing Record 12 of Set 14 | sorong
# Processing Record 13 of Set 14 | diu
# Processing Record 14 of Set 14 | mae hong son
# Processing Record 15 of Set 14 | kurunegala
# Processing Record 16 of Set 14 | jubayl
# City not found. Skipping...
# Processing Record 17 of Set 14 | mufumbwe
# Processing Record 18 of Set 14 | adre
# Processing Record 19 of Set 14 | nagua
# Processing Record 20 of Set 14 | kaputa
# Processing Record 21 of Set 14 | price
# Processing Record 22 of Set 14 | kirakira
# Processing Record 23 of Set 14 | wahiawa
# Processing Record 24 of Set 14 | mount vernon
# Processing Record 25 of Set 14 | itarema
# Processing Record 26 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 14 | sokoni
# Processing Record 29 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 14 | mahbubnagar
# Processing Record 31 of Set 14 | baoshan
# Processing Record 32 of Set 14 | hualmay
# Processing Record 33 of Set 14 | dona ines
# Processing Record 34 of Set 14 | antalaha
# Processing Record 35 of Set 14 | mao
# Processing Record 36 of Set 14 | tiarei
# Processing Record 37 of Set 14 | fort nelson
# Processing Record 38 of Set 14 | sabang
# Processing Record 39 of Set 14 | bolivar
# Processing Record 40 of Set 14 | baran
# Processing Record 41 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 14 | semey
# Processing Record 43 of Set 14 | maragogi
# Processing Record 44 of Set 14 | rio gallegos
# Processing Record 45 of Set 14 | rafaela
# Processing Record 46 of Set 14 | bobo dioulasso
# Processing Record 47 of Set 14 | ucluelet
# Processing Record 48 of Set 14 | port-gentil
# Processing Record 49 of Set 14 | luderitz
# Processing Record 50 of Set 14 | luwingu
# Processing Record 1 of Set 15 | winnemucca
# Processing Record 2 of Set 15 | poum
# Processing Record 3 of Set 15 | fukue
# Processing Record 4 of Set 15 | tahta
# Processing Record 5 of Set 15 | bengkulu
# Processing Record 6 of Set 15 | jalor
# Processing Record 7 of Set 15 | bichura
# Processing Record 8 of Set 15 | vanimo
# Processing Record 9 of Set 15 | mbuguni
# Processing Record 10 of Set 15 | olafsvik
# Processing Record 11 of Set 15 | banjar
# Processing Record 12 of Set 15 | bela
# Processing Record 13 of Set 15 | wilmington
# Processing Record 14 of Set 15 | egvekinot
# Processing Record 15 of Set 15 | livny
# Processing Record 16 of Set 15 | lucea
# Processing Record 17 of Set 15 | afzalpur
# Processing Record 18 of Set 15 | deputatskiy
# Processing Record 19 of Set 15 | santona
# Processing Record 20 of Set 15 | vanavara
# Processing Record 21 of Set 15 | loningen
# Processing Record 22 of Set 15 | santa isabel do rio negro
# Processing Record 23 of Set 15 | bay roberts
# Processing Record 24 of Set 15 | mwene-ditu
# Processing Record 25 of Set 15 | dali
# Processing Record 26 of Set 15 | mackenzie
# Processing Record 27 of Set 15 | kayankulam
# Processing Record 28 of Set 15 | cabo rojo
# Processing Record 29 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 15 | cape canaveral
# Processing Record 32 of Set 15 | north battleford
# Processing Record 33 of Set 15 | balikpapan
# Processing Record 34 of Set 15 | pedro escobedo
# Processing Record 35 of Set 15 | wilmington island
# Processing Record 36 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 15 | usinsk
# Processing Record 38 of Set 15 | batagay-alyta
# Processing Record 39 of Set 15 | mgandu
# Processing Record 40 of Set 15 | siderno
# Processing Record 41 of Set 15 | kalianget
# Processing Record 42 of Set 15 | sur
# Processing Record 43 of Set 15 | the valley
# Processing Record 44 of Set 15 | ciechocinek
# Processing Record 45 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 46 of Set 15 | goshogawara
# Processing Record 47 of Set 15 | ixtapa
# Processing Record 48 of Set 15 | kenai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Nampula -15.1165   39.2666     69.69        96         100        3.40
# 1      Padang  -0.9492  100.3543     73.45        84         100        2.91
# 2   Busselton -33.6500  115.3333     66.47        40           0       10.20
# 3  Port Hardy  50.6996 -127.4199     42.98        93         100       10.36
# 4     Rikitea -23.1203 -134.9692     78.33        72          60       10.74
# 5        Hovd  48.0056   91.6419     -5.53        81           6        2.21
# 6    Karasjok  69.4719   25.5112      1.40        99         100        6.40
# 7     Bilecik  40.0000   30.1667     30.88        53          34        2.86
# 8      Albany  42.6001  -73.9662     25.52        73           6        3.33
# 9    Victoria  22.2855  114.1577     63.95        77          90        8.01
#
#   Country Current Description
# 0      MZ          light rain
# 1      ID     overcast clouds
# 2      AU           clear sky
# 3      CA          light rain
# 4      PF       broken clouds
# 5      MN           clear sky
# 6      NO     overcast clouds
# 7      TR    scattered clouds
# 8      US           clear sky
# 9      HK     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Nampula      MZ -15.1165   39.2666     69.69        96         100
# 1      Padang      ID  -0.9492  100.3543     73.45        84         100
# 2   Busselton      AU -33.6500  115.3333     66.47        40           0
# 3  Port Hardy      CA  50.6996 -127.4199     42.98        93         100
# 4     Rikitea      PF -23.1203 -134.9692     78.33        72          60
# 5        Hovd      MN  48.0056   91.6419     -5.53        81           6
# 6    Karasjok      NO  69.4719   25.5112      1.40        99         100
# 7     Bilecik      TR  40.0000   30.1667     30.88        53          34
# 8      Albany      US  42.6001  -73.9662     25.52        73           6
# 9    Victoria      HK  22.2855  114.1577     63.95        77          90
#
#    Wind Speed Current Description
# 0        3.40          light rain
# 1        2.91     overcast clouds
# 2       10.20           clear sky
# 3       10.36          light rain
# 4       10.74       broken clouds
# 5        2.21           clear sky
# 6        6.40     overcast clouds
# 7        2.86    scattered clouds
# 8        3.33           clear sky
# 9        8.01     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
